# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
import seaborn as sns
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

from seaborn import relplot

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips)

# %%
sns.relplot(x  = tips['total_bill'], y = tips['tip'], data = tips, hue = 'smoker')

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="smoker", style="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", size="size", sizes = (20, 100))
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
from numpy.random import randn
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))
df
# Out:
#      time      value
# 0       0   1.532344
# 1       1   0.254798
# 2       2   0.053665
# 3       3  -1.529423
# 4       4  -3.163274
# ..    ...        ...
# 495   495 -13.172626
# 496   496 -14.260314
# 497   497 -14.511526
# 498   498 -12.981518
# 499   499 -11.946143
#
# [500 rows x 2 columns]

# %%
relplot(x = 'time', y = 'value', kind = 'line', data = df)

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
# fig, ax = plt.subplots()
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, label = 'signal', height = 4, aspect=2)
plt.legend(loc = 'right')

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line',estimator = None,  data = fmri, label = 'signal', height = 4, aspect=2)
plt.legend(loc = 'right')

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, hue='event', label = 'signal', height = 4, aspect=2)
plt.legend(loc = 'right')

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, hue='event',  style = 'region', label = 'signal', height = 4, aspect=2)
plt.legend(loc = 'right')

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'scatter', data = fmri, hue='event',  style = 'region', label = 'signal', height = 4, aspect=2)
plt.legend(loc = 'right')

# %%
dots = sns.load_dataset('dots').query("align == 'dots'")
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 389  dots     T2   680        3.2    37.806267
# 390  dots     T2   700        0.0    43.464959
# 391  dots     T2   700        3.2    38.994559
# 392  dots     T2   720        0.0    41.987121
# 393  dots     T2   720        3.2    41.716057
#
# [394 rows x 5 columns]

# %%
relplot(x = "time", y = 'firing_rate', data = dots, kind = 'line')

# %%
relplot(x = "time", y = 'firing_rate', data = dots, kind = 'line', hue = 'coherence', style ='choice' )

# %%
relplot(x = "time", y = 'firing_rate', data = dots, kind = 'line', hue = 'coherence', style ='choice', size = 'choice' )

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from seaborn import relplot
from numpy.random import randn

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
relplot(x = 'total_bill', y = 'tip' ,kind = 'line' ,  hue = 'smoker',  col = 'smoker', data = tips)

# %%
relplot(x = 'total_bill', y = 'tip' ,kind = 'scatter' ,  hue = 'smoker',  col = 'smoker', data = tips)

# %%
relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', data = tips, row = 'size')

# %%
relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = tips, col_wrap = 3)

# %%
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt 

from seaborn import relplot

# %%
fmri = sns.load_dataset('fmri')

# %%
sns.lineplot(x = 'timepoint', y = 'signal', style = 'event', hue = 'region', data = fmri , markers = True, errorbar=('ci', 68), err_style = 'bars')
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x = 'timepoint', y = 'signal', style = 'event', hue = 'event',
             data = fmri.query("region == 'frontal'") ,
              estimator=None)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
tips = sns.load_dataset('tips')

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', size ='size', style = 'time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x = 'day', y ='total_bill', data = tips, hue = 'day')

# %%
sns.catplot(x = 'day', y ='total_bill', data = tips, hue = 'day', jitter = False)

# %%
sns.catplot(x = 'day', y ='total_bill', data = tips, hue = 'day', kind = 'swarm')

# %%
sns.catplot(x = 'day', y ='total_bill', data = tips, hue = 'size', kind = 'swarm')

# %%
sns.catplot(x = 'day', y ='total_bill', data = tips, hue = 'smoker', jitter = True)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue ='day')

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue ='sex')

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue ='sex', dodge = False)

# %%
diamonds = sns.load_dataset('diamonds')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds, hue = 'cut')

# %%
sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds, dodge = False, hue = 'cut')

# %%
tips = sns.load_dataset('tips')

# %%
g = sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = "swarm")

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'violin', hue = 'sex', split = True, ax = g.ax)
# Out:
# c:\Users\arash\AppData\Local\ooba\ooba\text-generation-ui\installer_files\conda\lib\site-packages\seaborn\categorical.py:2761: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try violinplot
#   warnings.warn(msg, UserWarning)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

from seaborn import relplot

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
sns.catplot(x = 'sex', y = 'survived', kind = 'bar', data = titanic, hue = 'sex')

# %%
sns.catplot(x = 'sex', y = 'survived', kind = 'bar', data = titanic, hue = 'class')

# %%
sns.catplot(x = 'sex', y = 'survived', kind = 'bar', data = titanic, hue = 'class', palette = 'ch:0.43' )

# %%
sns.catplot(x = 'sex', y = 'survived', kind = 'point', data = titanic, hue = 'class' )

# %%
tips = sns.load_dataset('tips')

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 130       19.08  1.50    Male     No  Thur   Lunch     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 61        13.81  2.00    Male    Yes   Sat  Dinner     2
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 70        12.02  1.97    Male     No   Sat  Dinner     2

# %%
sns.jointplot(data=tips, x='total_bill', y='tip')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind = 'hex')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind = 'kde')
# Out:
# c:\Users\arash\AppData\Local\ooba\ooba\text-generation-ui\installer_files\conda\lib\site-packages\seaborn\distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'estimator'
#   cset = contour_func(

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# Create a filled KDE jointplot
sns.jointplot(
    data=tips, 
    x='total_bill', 
    y='tip', 
    kind='kde',
    fill = True)
