# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("penguins.csv")

# %%
df[:5]
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %%
df['Species'].value_counts()
# Out:
# Species
# Adelie Penguin (Pygoscelis adeliae)          152
# Gentoo penguin (Pygoscelis papua)            124
# Chinstrap penguin (Pygoscelis antarctica)     68
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     10
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               290
# dtype: int64

# %%
df.columns
# Out:
# Index(['studyName', 'Sample Number', 'Species', 'Region', 'Island', 'Stage',
#        'Individual ID', 'Clutch Completion', 'Date Egg', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex',
#        'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)', 'Comments'],
#       dtype='object')

# %%
selected_columns = [
    'Species',
    'Island',
    'Culmen Length (mm)',
    'Culmen Depth (mm)',
    'Body Mass (g)',
    'Sex'
]

# %%
df_selected = df[selected_columns]

# %%
df_selected
# Out:
#                                        Species     Island  Culmen Length (mm)  \
# 0          Adelie Penguin (Pygoscelis adeliae)  Torgersen                39.1
# 1          Adelie Penguin (Pygoscelis adeliae)  Torgersen                39.5
# 2          Adelie Penguin (Pygoscelis adeliae)  Torgersen                40.3
# 3          Adelie Penguin (Pygoscelis adeliae)  Torgersen                 NaN
# 4          Adelie Penguin (Pygoscelis adeliae)  Torgersen                36.7
# ..                                         ...        ...                 ...
# 339  Chinstrap penguin (Pygoscelis antarctica)      Dream                55.8
# 340  Chinstrap penguin (Pygoscelis antarctica)      Dream                43.5
# 341  Chinstrap penguin (Pygoscelis antarctica)      Dream                49.6
# 342  Chinstrap penguin (Pygoscelis antarctica)      Dream                50.8
# 343  Chinstrap penguin (Pygoscelis antarctica)      Dream                50.2
#
#      Culmen Depth (mm)  Body Mass (g)     Sex
# 0                 18.7         3750.0    MALE
# 1                 17.4         3800.0  FEMALE
# 2                 18.0         3250.0  FEMALE
# 3                  NaN            NaN     NaN
# 4                 19.3         3450.0  FEMALE
# ..                 ...            ...     ...
# 339               19.8         4000.0    MALE
# 340               18.1         3400.0  FEMALE
# 341               18.2         3775.0    MALE
# 342               19.0         4100.0    MALE
# 343               18.7         3775.0  FEMALE
#
# [344 rows x 6 columns]

# %%
df_selected.isnull().sum()
# Out:
# Species                0
# Island                 0
# Culmen Length (mm)     2
# Culmen Depth (mm)      2
# Body Mass (g)          2
# Sex                   10
# dtype: int64
