# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Failed to start the Kernel 'Python (Graphrag) (Python 3.10.10)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. EINVAL: invalid argument, mkdir 'c:\c:\Users\arash\AppData\Roaming\Cursor\User\globalStorage\ms-toolsai.jupyter\version-2025.3.0\jupyter\runtime'

# %%
jupyter --paths
jupyter --config-dir

# %%
df = pd.read_csv("penguins.csv")

# %%
df[:5]

# %%
df['Species'].value_counts()

# %%
df.isnull().sum()

# %%
df.columns

# %%
selected_columns = [
    'Species',
    'Island',
    'Culmen Length (mm)',
    'Culmen Depth (mm)',
    'Body Mass (g)',
    'Sex'
]

# %%
df_selected = df[selected_columns]

# %%
df_selected

# %%
df_selected.isnull().sum()

# %%
df['sex'].value_count()
