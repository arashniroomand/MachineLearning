# %%
import numpy as np 
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
sns.pairplot(iris)

# %%
plt.rcParams['figure.figsize'] = [10, 3]
plt.rcParams['figure.dpi'] = 150

iris.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## For large scale

# %%
iris.plot(logy = True, logx = True)
plt.title('iris dataset plot')
plt.xlabel('samples (log scale)')
plt.ylabel('lenght / width')

plt.show()

# %%
x = iris[['sepal_width', 'sepal_length']]
y = iris[['petal_width', 'petal_length']]

# %%
ax = y.plot()
x.plot(ax = ax)
# Out:
# <Axes: >

# %%
plt.rcParams['figure.figsize'] = [10, 5]
plt.rcParams['figure.dpi'] = 150
ax = x.plot()
ax2 = y.plot(ax = ax, secondary_y=True)

ax.set_ylabel('sepal ( width and length)')
ax2.set_ylabel('petal ( width and length)')

ax.set_xlabel('#Samples')
ax.set_title('Secondary Axis Plot')
# Out:
# Text(0.5, 1.0, 'Secondary Axis Plot')

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns

import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris')

# %%
df = iris.iloc[0][0:4]

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df.plot.bar(color = 'green', fontsize = 10, title = 'IRIS Bar Plot', ylabel = 'length/width', grid = True, ylim = (0, 10))
# Out:
# <Axes: title={'center': 'IRIS Bar Plot'}, ylabel='length/width'>

# %%
df.plot.bar(color = 'green', fontsize = 10, title = 'IRIS Bar Plot', ylabel = 'length/width', grid = True, ylim = (0, 10), rot = 20)

plt.figure()
df.plot.barh(color = 'green', fontsize = 10, title = 'IRIS Bar Plot', ylabel = 'length/width', grid = True, ylim = (0, 10), rot = 20)
# Out:
# <Axes: title={'center': 'IRIS Bar Plot'}, ylabel='length/width'>

# %%
df.plot.pie(title = 'IRIS Bar Plot', ylabel = 'length/width', rot = 20)
# Out:
# C:\Users\arash\AppData\Local\Temp\ipykernel_31360\1842011599.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.plot.pie(title = 'IRIS Bar Plot', ylabel = 'length/width', rot = 20)
# <Axes: title={'center': 'IRIS Bar Plot'}, ylabel='length/width'>

# %%
iris.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', bins = 50, stacked = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.hist(color = 'b', grid = True, alpha = 0.6)

plt.tight_layout()
plt.show()

# %%
iris.plot.box()
# Out:
# <Axes: >

# %%
ax = iris.plot(kind = 'area', figsize=(10,5), stacked=False)

# %%
iris.plot.scatter(x = 'sepal_width', y = 'sepal_length')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris[iris['species'] == 'versicolor'].plot.scatter(x = 'sepal_width', y = 'sepal_length',
                                                   c = 'petal_length')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
iris.plot.hexbin(x = 'sepal_width', y = 'sepal_length',
                                                   C = 'petal_length', gridsize = 10, 
                                                   cmap = 'viridis')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.sample()
# Out:
#      survived  pclass   sex   age  ...  deck  embark_town  alive alone
# 244         0       3  male  30.0  ...   NaN    Cherbourg     no  True
#
# [1 rows x 15 columns]

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = iris.drop('species', axis = 1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot.pie(figsize = (5,5), fontsize = 10)
# Out:
# <Axes: ylabel='0'>

# %%
ax = df.head(3).T.plot.pie(figsize = (10,10), fontsize = 5,
                           subplots = True, legend = True,
                           autopct = "%0.2f%%")
ax[0].legend(bbox_to_anchor = (1,1.5))
ax[1].legend(bbox_to_anchor = (1,1.5))
ax[2].legend(bbox_to_anchor = (1,1.5))

plt.tight_layout()

# %%
ax = df.plot(subplots = True, sharex = False)

plt.tight_layout()

# %%
ax = df.plot(figsize = (10,5),subplots = True, sharex = False, layout = (2,2))

plt.tight_layout()
